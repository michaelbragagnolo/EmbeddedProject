# %% [markdown]
# ***
# ## Generative Replay
#
# Experiment reproducing **Generative Replay** strategy:
# Deep Generative Replay for a Scholar consisting of a Solver and Generator.
#
# *Code implements Deep Generative Replay as described in:*
# - Deep Generative Replay: https://arxiv.org/abs/1705.08690
# ***

# %%
# --- LIBRARIES AND UTILS ---
import argparse
import unittest

# Avalanche library from ContinualAI
import avalanche

from avalanche.models import SimpleMLP
from avalanche.benchmarks.datasets import MNIST
from avalanche.benchmarks.generators import nc_benchmark
from torchvision.transforms import Compose, ToTensor, Normalize, RandomCrop

import torch
from torch.nn import CrossEntropyLoss
from torch.optim import Adam

# Loggers
from avalanche.logging import InteractiveLogger, TensorboardLogger

# Evaluation
from avalanche.training.plugins import GenerativeReplayPlugin, EvaluationPlugin
from avalanche.evaluation.metrics import accuracy_metrics, timing_metrics, forgetting_metrics

# Extras: Model and utils
from utils import arguments, get_average_metric, get_target_result

# %% [markdown]
# ***
# ### Generator: VAE
#
# The generator implemented in *GenerativeModel.py* is hereafter wrapped into a trainable strategy, to be passed to the generator_strategy parameter when using Deep Generative Replay learning strategy.

# %%
# --- custom imports

# Import the VAE generative model and its loss function
from imports.GenerativeModel import VAE_model, VAE_loss
# Import the VAE training class
from imports.TrainingInstances import VAE_TrainingStrategy

# Generative Model
generator = VAE_model((1, 28, 28), nhid=2, device=None)

# Optimizer of the generator
optimizer_generator = Adam(filter(lambda p: p.requires_grad, generator.parameters()),
    lr=0.01,
    weight_decay=0.0001)

# ..this is what to pass to the generator_strategy parameter of GR
generator_TrainableStrategy= VAE_TrainingStrategy(generator, optimizer_generator, VAE_loss,
    # additional arguments
    train_mb_size=100,
    train_epochs =4,
    eval_mb_size =1,
    device =None,
                                                   
    # the trainable strategy has to employ GenerativeReplayPlugin()
    # GenerativeReplayPlugin(None) as it is the model itself [strategy.model (VAE_model)] to be trained
    plugins=[GenerativeReplayPlugin(
        replay_size=100,               # batch size of replay added to each data batch
        increasing_replay_size=False,  # if True, double replay data added to each batch
    )])

# %% [markdown]
# ***
# ### Generative Replay strategy
#
# **Generative Replay** strategy using a solver-generator pair

# %%
# --- GENERATIVE REPLAY TECHNIQUE ---
# Import the Generative Replay strategy instance
from imports.TrainingInstances import GR


class GenRepl(unittest.TestCase): #TestCase class

    # Split-MNIST benchmark
    def test_smnist(self, override_args=None):

        # --- CONFIG
        device = torch.device(f"cuda:{args.cuda}"
            if torch.cuda.is_available() and args.cuda >= 0
            else "cpu")
        

        # --- BENCHMARK and SCENARIO
        train_transform = Compose([RandomCrop(28, padding=4), ToTensor(), Normalize((0.1307,), (0.3081,)) ])
        test_transform  = Compose([ToTensor(), Normalize((0.1307,), (0.3081,)) ])

        mnist_train = MNIST('./data/mnist', train=True, download=True, transform=train_transform)
        mnist_test  = MNIST('./data/mnist', train=False, download=True, transform=test_transform)
        
        
        scenario = nc_benchmark(train_dataset= mnist_train,
                                test_dataset = mnist_test,
                                n_experiences= 5,
                                task_labels  = False)
        # ---------
        
        # --- Strategy instantiation --- # 
        # 1. Model: SOLVER
        # 2. Optimizer of the solver
        # 3. Loss function of the solver
        
        # ADDITIONAL ARGUMENTS allow to customize training
        args = arguments({ 'cuda': 0,              # GPU or CPU
                           'train_epochs': 2,      # Training epochs
                           'train_mb_size': 100,   # Train minibatch size
                           'eval_mb_size' : 100,   # Eval minibatch size
                            }, override_args) 

        # Solver model: simple classifier
        model = SimpleMLP(num_classes=10, input_size=28*28, hidden_size=400, hidden_layers=2, drop_rate=0)
        
        # Optimizer of the solver
        optimizer = Adam(model.parameters(), lr=0.001)
        
        # Loss function of the solver
        criterion = CrossEntropyLoss()
        
        # --- EVALUATION --- #
        # Metrics of main interest to be tracked
        eval_plugin = EvaluationPlugin(
            accuracy_metrics(minibatch=True, epoch=True, experience=True, stream=True),
            #timing_metrics(epoch=True),
            #forgetting_metrics(experience=True, stream=True),
            loggers=[InteractiveLogger()], # displays a progress bar during training and evaluation
            #loggers=[],
            benchmark=scenario
        )

        # --- STRATEGY INSTANCE --- #
        cl_strategy = GR(model, optimizer, criterion,
            # additional arguments
            train_mb_size = args.train_mb_size,
            eval_mb_size  = args.eval_mb_size, 
            train_epochs  = args.train_epochs,
            device = device,                                       
            # evaluation
            evaluator = eval_plugin,                       
                                       
            # :param generator_strategy: GENERATOR wrapped into a trainable strategy
            generator_strategy = generator_TrainableStrategy
        )
        

        # --- TRAINING AND EVAL --- #
        print('Starting experiment...')
        
        for experience in scenario.train_stream:
            print('Current experience {}, contains: {} patterns'.format(experience.current_experience, len(experience.dataset)))
            print('Current classes: ',experience.classes_in_this_experience)
            
            # Train
            cl_strategy.train(experience)
            print('Training completed')
            
            # Accuracy over the whole test set (no access to task-ID at inference time)
            print('Computing accuracy over the whole test set')
            res = cl_strategy.eval(scenario.test_stream)
            
        
        avg_stream_acc = get_average_metric(res)
        print(f"Generative Replay - average stream accuracy: {avg_stream_acc:.2f}")

# %% [markdown]
# ### Run and Evaluate the experiment
# - Create an instance of the strategy object
# - Execute the strategy on a benchmark

# %%
# Create the strategy
s = GenRepl()

# Run the experiment with custom parameters
s.test_smnist()
# Out:
# Starting experiment...
# Current experience 0, contains: 12223 patterns
# Current classes:  [2, 7]
# -- >> Start of training phase << --
# 100%|██████████| 123/123 [00:04<00:00, 25.43it/s]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9322
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# 100%|██████████| 123/123 [00:04<00:00, 25.79it/s]
# Epoch 1 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9804
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 1.0000
# -- >> Start of training phase << --
# 100%|██████████| 123/123 [00:05<00:00, 20.54it/s]
# Epoch 0 ended.
# 100%|██████████| 123/123 [00:05<00:00, 20.80it/s]
# Epoch 1 ended.
# 100%|██████████| 123/123 [00:05<00:00, 20.93it/s]
# Epoch 2 ended.
# 100%|██████████| 123/123 [00:05<00:00, 20.98it/s]
# Epoch 3 ended.
# -- >> End of training phase << --
# -- >> End of training phase << --
# Training completed
# Computing accuracy over the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 21/21 [00:00<00:00, 37.31it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9636
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 19/19 [00:00<00:00, 37.55it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 20/20 [00:00<00:00, 37.17it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 22/22 [00:00<00:00, 38.51it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 20/20 [00:00<00:00, 37.28it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.1985
# Current experience 1, contains: 11339 patterns
# Current classes:  [5, 6]
# -- >> Start of training phase << --
# 100%|██████████| 114/114 [00:05<00:00, 19.39it/s]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8433
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9615
# 100%|██████████| 114/114 [00:05<00:00, 19.39it/s]
# Epoch 1 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9795
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9744
# -- >> Start of training phase << --
# 100%|██████████| 114/114 [00:07<00:00, 15.80it/s]
# Epoch 0 ended.
# 100%|██████████| 114/114 [00:07<00:00, 15.93it/s]
# Epoch 1 ended.
# 100%|██████████| 114/114 [00:07<00:00, 15.87it/s]
# Epoch 2 ended.
# 100%|██████████| 114/114 [00:07<00:00, 15.90it/s]
# Epoch 3 ended.
# -- >> End of training phase << --
# -- >> End of training phase << --
# Training completed
# Computing accuracy over the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 21/21 [00:00<00:00, 37.11it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7845
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 19/19 [00:00<00:00, 37.15it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.9886
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 20/20 [00:00<00:00, 36.69it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 22/22 [00:00<00:00, 37.42it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 20/20 [00:00<00:00, 37.00it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.3445
# Current experience 2, contains: 11872 patterns
# Current classes:  [0, 9]
# -- >> Start of training phase << --
# 100%|██████████| 119/119 [00:06<00:00, 19.27it/s]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8285
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9722
# 100%|██████████| 119/119 [00:06<00:00, 19.29it/s]
# Epoch 1 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9744
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9861
# -- >> Start of training phase << --
# 100%|██████████| 119/119 [00:07<00:00, 15.81it/s]
# Epoch 0 ended.
# 100%|██████████| 119/119 [00:07<00:00, 15.66it/s]
# Epoch 1 ended.
# 100%|██████████| 119/119 [00:07<00:00, 15.87it/s]
# Epoch 2 ended.
# 100%|██████████| 119/119 [00:07<00:00, 15.95it/s]
# Epoch 3 ended.
# -- >> End of training phase << --
# -- >> End of training phase << --
# Training completed
# Computing accuracy over the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 21/21 [00:00<00:00, 37.89it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3170
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 19/19 [00:00<00:00, 37.68it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.4216
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 20/20 [00:00<00:00, 37.27it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.9899
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 22/22 [00:00<00:00, 38.82it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 20/20 [00:00<00:00, 37.97it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.3402
# Current experience 3, contains: 12584 patterns
# Current classes:  [1, 4]
# -- >> Start of training phase << --
# 100%|██████████| 126/126 [00:06<00:00, 19.15it/s]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.8203
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9464
# 100%|██████████| 126/126 [00:06<00:00, 19.15it/s]
# Epoch 1 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9695
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9643
# -- >> Start of training phase << --
# 100%|██████████| 126/126 [00:07<00:00, 15.80it/s]
# Epoch 0 ended.
# 100%|██████████| 126/126 [00:07<00:00, 15.88it/s]
# Epoch 1 ended.
# 100%|██████████| 126/126 [00:07<00:00, 15.89it/s]
# Epoch 2 ended.
# 100%|██████████| 126/126 [00:08<00:00, 15.43it/s]
# Epoch 3 ended.
# -- >> End of training phase << --
# -- >> End of training phase << --
# Training completed
# Computing accuracy over the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 21/21 [00:00<00:00, 38.05it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2121
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 19/19 [00:00<00:00, 38.11it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.1270
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 20/20 [00:00<00:00, 36.41it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.4062
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 22/22 [00:00<00:00, 37.53it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.9967
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 20/20 [00:00<00:00, 37.07it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.3590
# Current experience 4, contains: 11982 patterns
# Current classes:  [8, 3]
# -- >> Start of training phase << --
# 100%|██████████| 120/120 [00:06<00:00, 19.06it/s]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.7195
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9573
# 100%|██████████| 120/120 [00:06<00:00, 19.02it/s]
# Epoch 1 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.9465
# 	Top1_Acc_MB/train_phase/train_stream/Task000 = 0.9451
# -- >> Start of training phase << --
# 100%|██████████| 120/120 [00:07<00:00, 15.76it/s]
# Epoch 0 ended.
# 100%|██████████| 120/120 [00:07<00:00, 15.49it/s]
# Epoch 1 ended.
# 100%|██████████| 120/120 [00:07<00:00, 15.75it/s]
# Epoch 2 ended.
# 100%|██████████| 120/120 [00:07<00:00, 15.76it/s]
# Epoch 3 ended.
# -- >> End of training phase << --
# -- >> End of training phase << --
# Training completed
# Computing accuracy over the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 21/21 [00:00<00:00, 38.82it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0209
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 19/19 [00:00<00:00, 39.22it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0768
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 20/20 [00:00<00:00, 37.21it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.1770
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 22/22 [00:00<00:00, 39.29it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.4672
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 20/20 [00:00<00:00, 38.64it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.9728
# -- >> End of eval phase << --
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.3456
# Generative Replay - average stream accuracy: 0.35
